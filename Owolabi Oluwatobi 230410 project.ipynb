# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Real_Estate_Sales_2001-2020_GL.csv')
data
# Out:
# C:\Users\SLEEMTEECH\AppData\Local\Temp\ipykernel_18092\623975561.py:1: DtypeWarning: Columns (8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('Real_Estate_Sales_2001-2020_GL.csv')
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997213 entries, 0 to 997212
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     997213 non-null  int64
#  1   List Year         997213 non-null  int64
#  2   Date Recorded     997211 non-null  object
#  3   Town              997213 non-null  object
#  4   Address           997162 non-null  object
#  5   Assessed Value    997213 non-null  float64
#  6   Sale Amount       997213 non-null  float64
#  7   Sales Ratio       997213 non-null  float64
#  8   Property Type     614767 non-null  object
#  9   Residential Type  608904 non-null  object
#  10  Non Use Code      289681 non-null  object
#  11  Assessor Remarks  149864 non-null  object
#  12  OPM remarks       9934 non-null    object
#  13  Location          197697 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 106.5+ MB

# %% [markdown]
# #Pandas project
# #1. Using Real Estate Dataset, remove redundant data
# #2. Find the total sales by Residential Type
# #3. Generate a new table that sort your data using column Sales Ratio from the highest to the minimum
# #4. Find the first 10 Sales with the highest amount in a dataframe
# #5. Return the min, the max and the total sales of Estate
# #6. Congratulations on your new job as a data analyst in a Real Estate company, we realize that as years goes by, we are begining to experience
# # changes in our sales, can you draw a conclusion for your new employer, the effect of time on the company sales?
# #7. Kindly advise the company, which town should they stop selling Estate
# #8. Base on your findings, advise the company, which town should we continue selling our Real Estate
# #9. We have different properties in our company, which property will you advise us to stop selling and which will you advise us to
# # sell more of it?
# #SAVE YOUR ANALYSIS WITH YOUR NAME AND YOUR STUDENT'S ID. GOODLUCK...

# %%
data[data['Town']=='***Unknown***']
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 444657          70086       2007    12/18/2007  ***Unknown***
#
#                 Address  Assessed Value  Sale Amount  Sales Ratio  \
# 444657  18 MATHIEU LANE         66540.0     282450.0     0.235582
#
#         Property Type Residential Type             Non Use Code  \
# 444657  Single Family    Single Family  07 - Change in Property
#
#        Assessor Remarks OPM remarks Location
# 444657              NaN         NaN      NaN

# %%
data.drop(index=444657, axis=0, inplace=True)

# %%
data
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
data.drop(['Non Use Code', 'Assessor Remarks', 'OPM remarks'], axis=1, inplace=True)

# %%
data
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
data.drop(columns='Location', inplace=True)

# %%
data
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 997212 entries, 0 to 997212
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     997212 non-null  int64
#  1   List Year         997212 non-null  int64
#  2   Date Recorded     997210 non-null  object
#  3   Town              997212 non-null  object
#  4   Address           997161 non-null  object
#  5   Assessed Value    997212 non-null  float64
#  6   Sale Amount       997212 non-null  float64
#  7   Sales Ratio       997212 non-null  float64
#  8   Property Type     614766 non-null  object
#  9   Residential Type  608903 non-null  object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 83.7+ MB

# %%
data.dropna(axis=0, inplace=True)

# %%
data
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# 5              200109       2020    12/09/2020           Avon
# ...               ...        ...           ...            ...
# 997207         190272       2019    08/03/2020         Wilton
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# 2            5 CHESTNUT DRIVE        130400.0     179900.0     0.724800
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 608899 entries, 1 to 997211
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     608899 non-null  int64
#  1   List Year         608899 non-null  int64
#  2   Date Recorded     608899 non-null  object
#  3   Town              608899 non-null  object
#  4   Address           608899 non-null  object
#  5   Assessed Value    608899 non-null  float64
#  6   Sale Amount       608899 non-null  float64
#  7   Sales Ratio       608899 non-null  float64
#  8   Property Type     608899 non-null  object
#  9   Residential Type  608899 non-null  object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 51.1+ MB

# %%
data.reset_index(drop=True)
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0               20002       2020    10/02/2020        Ashford
# 1              200212       2020    03/09/2021           Avon
# 2              200243       2020    04/13/2021           Avon
# 3              200377       2020    07/02/2021           Avon
# 4              200109       2020    12/09/2020           Avon
# ...               ...        ...           ...            ...
# 608894         190272       2019    08/03/2020         Wilton
# 608895         190272       2019    06/24/2020     New London
# 608896         190284       2019    11/27/2019      Waterbury
# 608897         190129       2019    04/27/2020  Windsor Locks
# 608898         190504       2019    06/03/2020     Middletown
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             390 TURNPIKE RD        253000.0     430000.0     0.588300
# 1            5 CHESTNUT DRIVE        130400.0     179900.0     0.724800
# ...

# %% [markdown]
# ### Find the total sales by Residential Type

# %%
data.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type', 'Profit'],
#       dtype='object')

# %%
data['Residential Type'].unique()
# Out:
# array(['Single Family', 'Condo', 'Two Family', 'Three Family',
#        'Four Family'], dtype=object)

# %%
data.groupby('Residential Type')['Sale Amount'].sum().sort_values(ascending=False)
# Out:
# Residential Type
# Single Family    1.781616e+11
# Condo            3.207528e+10
# Two Family       6.125224e+09
# Three Family     2.868037e+09
# Four Family      7.615052e+08
# Name: Sale Amount, dtype: float64

# %%
sns.barplot(x='Residential Type',y='Sale Amount', data=data)
# Out:
# <Axes: xlabel='Residential Type', ylabel='Sale Amount'>

# %% [markdown]
# ## 3. Generate a new table that sort your data using column Sales Ratio from the highest to the minimum

# %%
data.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type'],
#       dtype='object')

# %%
data1=data.sort_values('Sales Ratio', ascending=False)
data1
# Out:
#         Serial Number  List Year Date Recorded        Town  \
# 528256          90429       2009    05/05/2010   Greenwich
# 874177         170277       2017    01/09/2018   Stratford
# 870743         170276       2017    01/09/2018   Stratford
# 386502          60092       2006    01/30/2007  New Canaan
# 822121         160815       2016    06/27/2017   Stratford
# ...               ...        ...           ...         ...
# 721118         140978       2014    06/01/2015   Waterbury
# 51999         2000797       2020    01/15/2021    Stamford
# 17155          200186       2020    06/14/2021   Mansfield
# 9287           200088       2020    02/16/2021   Mansfield
# 38045         2000798       2020    01/15/2021    Stamford
#
#                             Address  Assessed Value  Sale Amount  Sales Ratio  \
# 528256        38 FRENCH ROAD,GRW,CT       6320090.0       3000.0  2106.696667
# 874177                   59 HULL CT      19099710.0      10000.0  1909.971000
# ...

# %%
data1.describe()
# Out:
#        Serial Number      List Year  Assessed Value   Sale Amount  \
# count   6.088990e+05  608899.000000    6.088990e+05  6.088990e+05
# mean    6.268159e+05    2013.721716    2.519887e+05  3.625687e+05
# std     8.021119e+06       4.464237    1.302122e+06  9.414882e+05
# min     8.200000e+01    2006.000000    0.000000e+00  0.000000e+00
# 25%     7.030600e+04    2010.000000    1.104600e+05  1.500000e+05
# 50%     1.304660e+05    2014.000000    1.596700e+05  2.350000e+05
# 75%     1.800920e+05    2018.000000    2.481000e+05  3.700000e+05
# max     2.000500e+09    2020.000000    8.815100e+08  3.187900e+08
#
#         Sales Ratio
# count  6.088990e+05
# mean   5.658947e+00
# std    1.800569e+03
# min    0.000000e+00
# 25%    5.865672e-01
# 50%    6.893000e-01
# 75%    8.396198e-01
# max    1.226420e+06

# %% [markdown]
# ## Find the first 10 Sales with the highest amount in a dataframe

# %%
data.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type'],
#       dtype='object')

# %%
data.sort_values('Sale Amount', ascending=False).head(10)
# Out:
#         Serial Number  List Year Date Recorded        Town  \
# 60894        20200078       2020    07/06/2021  Willington
# 65620        20200102       2020    09/28/2021  Willington
# 957543         191094       2019    08/12/2020     Norwalk
# 655816         130446       2013    04/11/2014   Greenwich
# 26964         2000815       2020    01/15/2021    Stamford
# 28506         2000814       2020    01/15/2021    Stamford
# 48425         2000809       2020    01/15/2021    Stamford
# 38045         2000798       2020    01/15/2021    Stamford
# 48333         2000795       2020    01/15/2021    Stamford
# 30399         2000810       2020    01/15/2021    Stamford
#
#                             Address  Assessed Value  Sale Amount  Sales Ratio  \
# 60894                224 RIVER ROAD        223070.0  318790019.0     0.000700
# 65620       7 TOLLAND TURNPIKE ROAD        112040.0  194149073.0     0.000577
# 957543                33 ORCHARD ST        507580.0  157000000.0     0.003200
# ...

# %% [markdown]
# ##  Return the min, the max and the total sales of Estate

# %%
data.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type'],
#       dtype='object')

# %%
data['Sale Amount'].min()
# Out:
# 487.0

# %%
data['Sale Amount'].max()
# Out:
# 318790019.0

# %%
data['Sale Amount'].sum()
# Out:
# 219991633169.16003

# %% [markdown]
# ### Congratulations on your new job as a data analyst in a Real Estate company, we realize that as years goes by, we are begining to experience
# ### changes in our sales, can you draw a conclusion for your new employer, the effect of time on the company sales?

# %%
data.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type', 'Profit'],
#       dtype='object')

# %%
data.groupby('List Year')['Sale Amount'].sum().sort_values(ascending=False)
# Out:
# List Year
# 2020    2.903971e+10
# 2019    2.040114e+10
# 2006    1.834753e+10
# 2016    1.786495e+10
# 2014    1.561284e+10
# 2018    1.467216e+10
# 2017    1.443045e+10
# 2009    1.319597e+10
# 2007    1.224179e+10
# 2015    1.214181e+10
# 2013    1.209532e+10
# 2012    1.181195e+10
# 2011    1.013518e+10
# 2008    9.011664e+09
# 2010    8.989172e+09
# Name: Sale Amount, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='List Year',y='Sale Amount', data=data)
# Out:
# <Axes: xlabel='List Year', ylabel='Sale Amount'>

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_data.corr(method='pearson')
correlation_matrix
# Out:
#                 Serial Number  List Year  Assessed Value  Sale Amount  \
# Serial Number        1.000000   0.076614       -0.001905     0.002295
# List Year            0.076614   1.000000        0.000714     0.012067
# Assessed Value      -0.001905   0.000714        1.000000     0.159276
# Sale Amount          0.002295   0.012067        0.159276     1.000000
# Sales Ratio         -0.002091  -0.009509        0.178421    -0.014668
# Profit               0.003135   0.007045       -0.778438     0.495722
#
#                 Sales Ratio    Profit
# Serial Number     -0.002091  0.003135
# List Year         -0.009509  0.007045
# Assessed Value     0.178421 -0.778438
# Sale Amount       -0.014668  0.495722
# Sales Ratio        1.000000 -0.166319
# Profit            -0.166319  1.000000

# %% [markdown]
# - **from the above table there is no relationship between the years and sales**

# %% [markdown]
# ## Kindly advise the company, which town should they stop selling Estate
# ## advise the company, which town should we continue selling our Real Estate

# %%
data['Profit']= data['Sale Amount'] - data['Assessed Value']
data
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# 5              200109       2020    12/09/2020           Avon
# ...               ...        ...           ...            ...
# 997207         190272       2019    08/03/2020         Wilton
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# 2            5 CHESTNUT DRIVE        130400.0     179900.0     0.724800
# ...

# %%
data.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type', 'Profit'],
#       dtype='object')

# %%
data.groupby('Town')['Profit'].mean().sort_values(ascending=False)
# Out:
# Town
# Willington    812526.955202
# Rocky Hill    683869.510427
# Darien        552087.229563
# Greenwich     484654.008176
# Westport      457850.203923
#                   ...
# Waterbury      26068.797169
# Berlin         23787.295594
# Stratford      18681.408341
# Bridgeport     16635.364100
# Hamden        -38183.955925
# Name: Profit, Length: 169, dtype: float64

# %% [markdown]
# - **the company should stop selling at Town(Willington, Rocky Hill, Darien, Greenwish, Westport) because of the low sales and should,**
# - **keep selling at(Waterbury, Berlin, Stratford, Bridgeport, Hamden)towns which happens to have the highest sales**

# %% [markdown]
# ### We have different properties in our company, which property will you advise us to stop selling and which will you advise us to sell more of it

# %%
data.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type', 'Profit'],
#       dtype='object')

# %%
data.groupby('Property Type')['Sale Amount'].mean().sort_values(ascending=False)
# Out:
# Property Type
# Residential      479124.123501
# Single Family    388887.558890
# Four Family      314437.285714
# Condo            258066.873328
# Two Family       199137.356131
# Three Family     179842.934525
# Name: Sale Amount, dtype: float64

# %%
sns.barplot(x='Property Type', y='Sale Amount', data=data)
# Out:
# <Axes: xlabel='Property Type', ylabel='Sale Amount'>

# %% [markdown]
# - **from the gragh the company should keep selling more Residential Property type and
# should stop selling Three Family Property Type**

# %%
data.reset_index(drop=True)
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0               20002       2020    10/02/2020        Ashford
# 1              200212       2020    03/09/2021           Avon
# 2              200243       2020    04/13/2021           Avon
# 3              200377       2020    07/02/2021           Avon
# 4              200109       2020    12/09/2020           Avon
# ...               ...        ...           ...            ...
# 606767         190272       2019    08/03/2020         Wilton
# 606768         190272       2019    06/24/2020     New London
# 606769         190284       2019    11/27/2019      Waterbury
# 606770         190129       2019    04/27/2020  Windsor Locks
# 606771         190504       2019    06/03/2020     Middletown
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             390 TURNPIKE RD        253000.0     430000.0     0.588300
# 1            5 CHESTNUT DRIVE        130400.0     179900.0     0.724800
# ...

# %%
data.describe()
# Out:
#        Serial Number      List Year  Assessed Value   Sale Amount  \
# count   6.067720e+05  606772.000000    6.067720e+05  6.067710e+05
# mean    6.278847e+05    2013.730469    2.528042e+05  3.625612e+05
# std     8.029010e+06       4.460332    1.304096e+06  9.425757e+05
# min     8.200000e+01    2006.000000    5.000000e+00  4.870000e+02
# 25%     7.031700e+04    2010.000000    1.109400e+05  1.500000e+05
# 50%     1.304860e+05    2014.000000    1.600200e+05  2.350000e+05
# 75%     1.800952e+05    2018.000000    2.486000e+05  3.700000e+05
# max     2.000500e+09    2020.000000    8.815100e+08  3.187900e+08
#
#          Sales Ratio        Profit
# count  606772.000000  6.067710e+05
# mean        0.988706  1.097566e+05
# std         7.639361  1.482414e+06
# min         0.000000 -8.768300e+08
# 25%         0.587740  2.697000e+04
# 50%         0.690000  7.417000e+04
# 75%         0.840461  1.329950e+05
# max      2106.696667  3.185669e+08
