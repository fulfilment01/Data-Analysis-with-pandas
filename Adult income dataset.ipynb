# %%
import numpy as np
import pandas as pd

# %% [markdown]
# * How to fetch random samples from the Dataset?
# * isin
# * between
# * unique
# * dropna
# * replace
# * duplicated
# * drop_duplicates
# * astype
# * apply
# * What is Univariate analysis?
# * What is Bivariate analysis?
# * Memory Optimization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("adult.csv")
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
data = data.drop_duplicates()

# %%
alldata= data.copy()
alldata.sort_values(by="age", ascending=True, inplace=True)
alldata
# Out:
#        age  workclass  fnlwgt  education  educational-num      marital-status  \
# 22088   17    Private  221403       12th                8       Never-married
# 32593   17    Private  242773       11th                7       Never-married
# 32598   17    Private  133449        9th                5       Never-married
# 14359   17    Private  140117       11th                7       Never-married
# 14373   17    Private  124661       11th                7       Never-married
# ...    ...        ...     ...        ...              ...                 ...
# 27793   90    Private   87285    HS-grad                9       Never-married
# 48558   90    Private  313749    HS-grad                9             Widowed
# 25254   90    Private   46786  Bachelors               13  Married-civ-spouse
# 10735   90  Local-gov  188242    HS-grad                9       Never-married
# 28277   90    Private   40388  Bachelors               13       Never-married
#
# ...

# %%
alldata=alldata.reset_index(drop=True)
alldata
# Out:
#        age  workclass  fnlwgt  education  educational-num      marital-status  \
# 0       17    Private  221403       12th                8       Never-married
# 1       17    Private  242773       11th                7       Never-married
# 2       17    Private  133449        9th                5       Never-married
# 3       17    Private  140117       11th                7       Never-married
# 4       17    Private  124661       11th                7       Never-married
# ...    ...        ...     ...        ...              ...                 ...
# 48785   90    Private   87285    HS-grad                9       Never-married
# 48786   90    Private  313749    HS-grad                9             Widowed
# 48787   90    Private   46786  Bachelors               13  Married-civ-spouse
# 48788   90  Local-gov  188242    HS-grad                9       Never-married
# 48789   90    Private   40388  Bachelors               13       Never-married
#
# ...

# %%
alldata.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
alldata=alldata.dropna(axis="rows", how="any")
alldata
# Out:
#        age  workclass  fnlwgt  education  educational-num      marital-status  \
# 0       17    Private  221403       12th                8       Never-married
# 1       17    Private  242773       11th                7       Never-married
# 2       17    Private  133449        9th                5       Never-married
# 3       17    Private  140117       11th                7       Never-married
# 4       17    Private  124661       11th                7       Never-married
# ...    ...        ...     ...        ...              ...                 ...
# 48785   90    Private   87285    HS-grad                9       Never-married
# 48786   90    Private  313749    HS-grad                9             Widowed
# 48787   90    Private   46786  Bachelors               13  Married-civ-spouse
# 48788   90  Local-gov  188242    HS-grad                9       Never-married
# 48789   90    Private   40388  Bachelors               13       Never-married
#
# ...

# %%
alldata=alldata.replace("?", np.nan)
alldata
# Out:
#        age  workclass  fnlwgt  education  educational-num      marital-status  \
# 0       17    Private  221403       12th                8       Never-married
# 1       17    Private  242773       11th                7       Never-married
# 2       17    Private  133449        9th                5       Never-married
# 3       17    Private  140117       11th                7       Never-married
# 4       17    Private  124661       11th                7       Never-married
# ...    ...        ...     ...        ...              ...                 ...
# 48785   90    Private   87285    HS-grad                9       Never-married
# 48786   90    Private  313749    HS-grad                9             Widowed
# 48787   90    Private   46786  Bachelors               13  Married-civ-spouse
# 48788   90  Local-gov  188242    HS-grad                9       Never-married
# 48789   90    Private   40388  Bachelors               13       Never-married
#
# ...

# %%
alldata=alldata.dropna(axis=0)
alldata
# Out:
#        age  workclass  fnlwgt  education  educational-num      marital-status  \
# 0       17    Private  221403       12th                8       Never-married
# 1       17    Private  242773       11th                7       Never-married
# 2       17    Private  133449        9th                5       Never-married
# 3       17    Private  140117       11th                7       Never-married
# 4       17    Private  124661       11th                7       Never-married
# ...    ...        ...     ...        ...              ...                 ...
# 48785   90    Private   87285    HS-grad                9       Never-married
# 48786   90    Private  313749    HS-grad                9             Widowed
# 48787   90    Private   46786  Bachelors               13  Married-civ-spouse
# 48788   90  Local-gov  188242    HS-grad                9       Never-married
# 48789   90    Private   40388  Bachelors               13       Never-married
#
# ...

# %%
alldata=alldata.reset_index(drop=True)
alldata
# Out:
#        age  workclass  fnlwgt  education  educational-num      marital-status  \
# 0       17    Private  221403       12th                8       Never-married
# 1       17    Private  242773       11th                7       Never-married
# 2       17    Private  133449        9th                5       Never-married
# 3       17    Private  140117       11th                7       Never-married
# 4       17    Private  124661       11th                7       Never-married
# ...    ...        ...     ...        ...              ...                 ...
# 45170   90    Private   87285    HS-grad                9       Never-married
# 45171   90    Private  313749    HS-grad                9             Widowed
# 45172   90    Private   46786  Bachelors               13  Married-civ-spouse
# 45173   90  Local-gov  188242    HS-grad                9       Never-married
# 45174   90    Private   40388  Bachelors               13       Never-married
#
# ...

# %%
alldata.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45175.000000  4.517500e+04     45175.000000  45175.000000
# mean      38.556170  1.897388e+05        10.119314   1102.576270
# std       13.215349  1.056524e+05         2.551740   7510.249876
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173925e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45175.000000    45175.000000
# mean      88.687593       40.942512
# std      405.156611       12.007730
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
alldata.shape
# Out:
# (45175, 15)

# %%
print("Number of Rows", data.shape[0])
print("Number of Columns", data.shape[1])
# Out:
# Number of Rows 48790
# Number of Columns 15

# %% [markdown]
# ### Fetch Random Sample from the dataset

# %%
alldata.sample(frac=0.50)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 24585   39           Private  185099       HS-grad                9
# 41805   59  Self-emp-not-inc   78020       7th-8th                4
# 13873   30           Private  185177       HS-grad                9
# 27698   42         Local-gov  254817  Some-college               10
# 6391    24           Private  165107     Bachelors               13
# ...    ...               ...     ...           ...              ...
# 12681   29           Private  213842  Some-college               10
# 9092    26  Self-emp-not-inc  219897       Masters               14
# 4752    22           Private  196943       HS-grad                9
# 21144   36           Private  190759     Bachelors               13
# 14608   31           Private  100333          11th                7
#
#            marital-status         occupation   relationship   race  gender  \
# ...

# %%
alldata.sample(frac=0.50, random_state=100)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 1458    19           Private  100790       HS-grad                9
# 569     17           Private  438996          10th                6
# 16940   31           Private   25610     Preschool                1
# 45873   62  Self-emp-not-inc  136684       HS-grad                9
# 7808    24           Private  403671  Some-college               10
# ...    ...               ...     ...           ...              ...
# 24353   37       Federal-gov   33487  Some-college               10
# 41023   53           Private   48641          12th                8
# 3993    21           Private  321666       HS-grad                9
# 15176   30           Private  217296     Assoc-voc               11
# 6609    23           Private  271354       HS-grad                9
#
#            marital-status         occupation    relationship  \
# 1458        Never-married     Prof-specialty   Not-in-family
# ...

# %% [markdown]
# ### check null values in dataset and visualize it

# %%
alldata.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
 sns.heatmap(alldata.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Get the overall statistics about the dataframe

# %%
alldata.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45175.000000  4.517500e+04     45175.000000  45175.000000
# mean      38.556170  1.897388e+05        10.119314   1102.576270
# std       13.215349  1.056524e+05         2.551740   7510.249876
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173925e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45175.000000    45175.000000
# mean      88.687593       40.942512
# std      405.156611       12.007730
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
alldata.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   45175.000000     45175  4.517500e+04     45175     45175.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33262           NaN     14770              NaN
# mean       38.556170       NaN  1.897388e+05       NaN        10.119314
# std        13.215349       NaN  1.056524e+05       NaN         2.551740
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.173925e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783120e+05       NaN        10.000000
# 75%        47.000000       NaN  2.379030e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status    occupation relationship   race gender  \
# ...

# %%
alldata.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
alldata['education'].unique()
# Out:
# array(['12th', '11th', '9th', '10th', 'HS-grad', 'Some-college',
#        '7th-8th', '5th-6th', 'Masters', '1st-4th', 'Assoc-voc',
#        'Bachelors', 'Preschool', 'Assoc-acdm', 'Doctorate', 'Prof-school'],
#       dtype=object)

# %%
alldata['educational-num'].unique()
# Out:
# array([ 8,  7,  5,  6,  9, 10,  4,  3, 14,  2, 11, 13,  1, 12, 16, 15],
#       dtype=int64)

# %%
alldata.drop(columns='educational-num')

# %%
alldata
# Out:
#        age  workclass  fnlwgt  education      marital-status       occupation  \
# 0       17    Private  221403       12th       Never-married    Other-service
# 1       17    Private  242773       11th       Never-married    Other-service
# 2       17    Private  133449        9th       Never-married    Other-service
# 3       17    Private  140117       11th       Never-married            Sales
# 4       17    Private  124661       11th       Never-married            Sales
# ...    ...        ...     ...        ...                 ...              ...
# 45170   90    Private   87285    HS-grad       Never-married    Other-service
# 45171   90    Private  313749    HS-grad             Widowed     Adm-clerical
# 45172   90    Private   46786  Bachelors  Married-civ-spouse            Sales
# 45173   90  Local-gov  188242    HS-grad       Never-married     Craft-repair
# 45174   90    Private   40388  Bachelors       Never-married  Exec-managerial
#
# ...

# %% [markdown]
# ### drop the capital-gain and capital-loss

# %%
alldata.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'income'],
#       dtype='object')

# %%
alldata=alldata.drop(['capital-gain','capital-loss',], axis=1)
alldata
# Out:
#        age  workclass  fnlwgt  education      marital-status       occupation  \
# 0       17    Private  221403       12th       Never-married    Other-service
# 1       17    Private  242773       11th       Never-married    Other-service
# 2       17    Private  133449        9th       Never-married    Other-service
# 3       17    Private  140117       11th       Never-married            Sales
# 4       17    Private  124661       11th       Never-married            Sales
# ...    ...        ...     ...        ...                 ...              ...
# 45170   90    Private   87285    HS-grad       Never-married    Other-service
# 45171   90    Private  313749    HS-grad             Widowed     Adm-clerical
# 45172   90    Private   46786  Bachelors  Married-civ-spouse            Sales
# 45173   90  Local-gov  188242    HS-grad       Never-married     Craft-repair
# 45174   90    Private   40388  Bachelors       Never-married  Exec-managerial
#
# ...

# %% [markdown]
# # univariate Analysis

# %% [markdown]
# Univariate analysis is a statistical method used to analyze and describe the characteristics of a single variable. In other words, it focuses on examining the distribution, central tendency, and dispersion of a single variable without considering its relationship with other variables.
#
# The key objectives of univariate analysis include    :- **
#
# Descriptive Statis** tics: Univariate analysis helps in summarizing the main features of a dataset by providing measures such as mean, median, mode, range, variance, and standard deviat
# - **n.
#
# Visuali**zation: Graphical techniques such as histograms, box plots, and pie charts are commonly used in univariate analysis to visualize the distribution and patterns within a single vari- **ble.
#
# Detection of **Outliers: Univariate analysis can identify outliers or extreme values within a dataset that may skew the results or indicate errors in data coll- **ction.
#
# Understanding Data Di**stribution: It helps in understanding the shape and characteristics of the distribution of a variable, such as whether it follows a normal distribution, skewed distribution, or has multip- **e peaks.
#
# Identification of Pattern**s and Trends: Univariate analysis can reveal patterns and trends over time or across different categories within a singl    e   variable.
#
# While univariate analysis provides valuable insights into individual variables, it is often complemented by multivariate analysis, which explores the relationships between multiple variables simultaneously. Multivariate analysis helps in understanding the complex interactions and dependencies among variables, offering a more comprehensive understanding of the data.

# %% [markdown]
# #### whats the distribution of age column?

# %%
alldata.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
alldata['age'].describe()
# Out:
# count    45175.000000
# mean        38.556170
# std         13.215349
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
alldata['age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# #### find the total number of person having age between 17 to 48 (inclusive) using between method

# %%
alldata[(alldata['age']>=17) & (alldata['age']<=48)]
# Out:
#        age  workclass  fnlwgt     education      marital-status  \
# 0       17    Private  221403          12th       Never-married
# 1       17    Private  242773          11th       Never-married
# 2       17    Private  133449           9th       Never-married
# 3       17    Private  140117          11th       Never-married
# 4       17    Private  124661          11th       Never-married
# ...    ...        ...     ...           ...                 ...
# 34853   48    Private  377757          10th  Married-civ-spouse
# 34854   48    Private   47022       HS-grad             Widowed
# 34855   48    Private  172822  Some-college            Divorced
# 34856   48  Local-gov  317360       Masters  Married-civ-spouse
# 34857   48    Private   38819       Masters  Married-civ-spouse
#
#               occupation    relationship   race  gender  hours-per-week  \
# 0          Other-service       Own-child  Black    Male              18
# ...

# %%
sum((alldata['age']>=17) & (alldata['age']<=48))
# Out:
# 34858

# %%
alldata[alldata['age'].between(17,48)]
# Out:
#        age  workclass  fnlwgt     education      marital-status  \
# 0       17    Private  221403          12th       Never-married
# 1       17    Private  242773          11th       Never-married
# 2       17    Private  133449           9th       Never-married
# 3       17    Private  140117          11th       Never-married
# 4       17    Private  124661          11th       Never-married
# ...    ...        ...     ...           ...                 ...
# 34853   48    Private  377757          10th  Married-civ-spouse
# 34854   48    Private   47022       HS-grad             Widowed
# 34855   48    Private  172822  Some-college            Divorced
# 34856   48  Local-gov  317360       Masters  Married-civ-spouse
# 34857   48    Private   38819       Masters  Married-civ-spouse
#
#               occupation    relationship   race  gender  hours-per-week  \
# 0          Other-service       Own-child  Black    Male              18
# ...

# %%
sum(alldata['age'].between(17,48))
# Out:
# 34858

# %% [markdown]
# #### what is the distribution of workclass column?

# %%
alldata.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
alldata['workclass'].describe()
# Out:
# count       45175
# unique          7
# top       Private
# freq        33262
# Name: workclass, dtype: object

# %%
plt.figure(figsize=(10,10))
alldata['workclass'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### how many persons are having bachelors or masters degree?

# %%
alldata.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
filter1=alldata['education']=='Bachelors'
filter2=alldata['education']=='Masters'

# %%
alldata[filter1 | filter2]
# Out:
#        age  workclass  fnlwgt  education      marital-status       occupation  \
# 607     18  Local-gov  155905    Masters       Never-married   Prof-specialty
# 1434    19    Private  100999  Bachelors       Never-married   Prof-specialty
# 2502    20    Private  216436  Bachelors       Never-married            Sales
# 2769    20    Private  190227    Masters       Never-married  Exec-managerial
# 3024    21    Private  224632  Bachelors       Never-married     Adm-clerical
# ...    ...        ...     ...        ...                 ...              ...
# 45160   90    Private  313749  Bachelors       Never-married   Prof-specialty
# 45166   90    Private   88991  Bachelors  Married-civ-spouse  Exec-managerial
# 45167   90    Private  206667    Masters  Married-civ-spouse   Prof-specialty
# 45172   90    Private   46786  Bachelors  Married-civ-spouse            Sales
# 45174   90    Private   40388  Bachelors       Never-married  Exec-managerial
#
# ...

# %%
len(alldata[filter1 | filter2])
# Out:
# 10072

# %%
sum(alldata['education'].isin(['Bachelors', 'Masters']))
# Out:
# 10072

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Bivariate analysis is a statistical method used to explore the relationship between two different variables. Unlike univariate analysis, which focuses on analyzing a single variable at a time, bivariate analysis examines how two variables are related to each other.
#
# The main objectives of bivariate analysis include:
#
# - **Understanding Relationships**: Bivariate analysis helps in understanding the relationship, association, or correlation between two variables. It allows researchers to determine whether changes in one variable are associated with changes in the other variable.
#
# - **Exploring Dependencies**: Bivariate analysis helps in exploring dependencies between two variables. It identifies whether changes in one variable are dependent on the values of the other variable.
#
# - **Identifying Patterns and Trends**: Bivariate analysis can reveal patterns and trends that emerge when two variables are considered together. It helps in understanding how the values of one variable vary with the values of another variable.
#
# - **Predictive Modeling**: In predictive modeling and machine learning, bivariate analysis can be used to identify important predictor variables that are strongly associated with the target variable.
#
# - **Visualization**: Graphical techniques such as scatter plots, line plots, and heatmaps are commonly used in bivariate analysis to visualize the relationship between two variables.
#
# - **Hypothesis Testing**: Bivariate analysis can be used to test hypotheses about the relationship between two variables. Statistical tests such as correlation analysis, t-tests, chi-square tests, and ANOVA are often used to assess the significance of the relationship.
#
# *Bivariate analysis forms the foundation for more advanced multivariate analysis techniques, which involve the simultaneous analysis of three or more variables. By understanding the relationship between two variables, researchers can gain insights into complex systems and phenomena, leading to better decision-making and problem-solving in various fields such as economics, social sciences, healthcare, and engineering.*

# %%
alldata.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
sns.boxplot(x='income', y='age', data=alldata)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %% [markdown]
# #### replace salary values['<=50k','>50k'] with 0 and 1

# %%
alldata.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
alldata['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
alldata['income'].value_counts()
# Out:
# income
# <=50K    33973
# >50K     11202
# Name: count, dtype: int64

# %%
sns.countplot(x='income', data=alldata)
# Out:
# <Axes: xlabel='income', ylabel='count'>

# %%
def income_data(inc):
    if inc=='<=50K':
        return 0
    else:
        return 1

# %%
alldata['encoded_salary']=alldata['income'].apply(income_data)
alldata.head(10)
# Out:
#    age  workclass  fnlwgt education marital-status      occupation  \
# 0   17    Private  221403      12th  Never-married   Other-service
# 1   17    Private  242773      11th  Never-married   Other-service
# 2   17    Private  133449       9th  Never-married   Other-service
# 3   17    Private  140117      11th  Never-married           Sales
# 4   17    Private  124661      11th  Never-married           Sales
# 5   17    Private   94492      11th  Never-married           Sales
# 6   17    Private   73820      12th  Never-married           Sales
# 7   17  Local-gov  292285      11th  Never-married  Prof-specialty
# 8   17    Private  116267      12th  Never-married    Craft-repair
# 9   17  Local-gov   39815      10th  Never-married   Other-service
#
#   relationship   race  gender  hours-per-week native-country income  \
# 0    Own-child  Black    Male              18  United-States  <=50K
# 1    Own-child  White  Female              20  United-States  <=50K
# ...

# %%
# another method
alldata.replace(to_replace=['<=50K', '>50K'], value=[0,1], inplace=True)
alldata.tail(10)
# Out:
#        age  workclass  fnlwgt     education      marital-status  \
# 45165   90    Private   52386  Some-college       Never-married
# 45166   90    Private   88991     Bachelors  Married-civ-spouse
# 45167   90    Private  206667       Masters  Married-civ-spouse
# 45168   90    Private   51744       HS-grad       Never-married
# 45169   90    Private   90523       HS-grad             Widowed
# 45170   90    Private   87285       HS-grad       Never-married
# 45171   90    Private  313749       HS-grad             Widowed
# 45172   90    Private   46786     Bachelors  Married-civ-spouse
# 45173   90  Local-gov  188242       HS-grad       Never-married
# 45174   90    Private   40388     Bachelors       Never-married
#
#              occupation   relationship                race  gender  \
# 45165     Other-service  Not-in-family  Asian-Pac-Islander    Male
# 45166   Exec-managerial           Wife               White  Female
# ...

# %% [markdown]
# #### which workclass is getting the highest salary?

# %%
alldata.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'encoded_salary'],
#       dtype='object')

# %%
alldata.groupby('workclass')['income'].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.554407
# Federal-gov         0.390469
# Local-gov           0.295161
# Self-emp-not-inc    0.279051
# State-gov           0.267215
# Private             0.217816
# Without-pay         0.095238
# Name: income, dtype: float64

# %% [markdown]
# #### who has better chance to get salary >50k male or female?

# %%
alldata.groupby('gender')['income'].mean().sort_values(ascending=False)
# Out:
# gender
# Male      0.312609
# Female    0.113692
# Name: income, dtype: float64

# %% [markdown]
# ### convert workclass columns datatype to category datatype

# %%
alldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45175 entries, 0 to 45174
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  object
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  income          45175 non-null  int64
#  12  encoded_salary  45175 non-null  int64
# dtypes: int64(5), object(8)
# memory usage: 4.5+ MB

# %%
alldata['workclass']=alldata['workclass'].astype('category')
alldata
# Out:
#        age  workclass  fnlwgt  education      marital-status       occupation  \
# 0       17    Private  221403       12th       Never-married    Other-service
# 1       17    Private  242773       11th       Never-married    Other-service
# 2       17    Private  133449        9th       Never-married    Other-service
# 3       17    Private  140117       11th       Never-married            Sales
# 4       17    Private  124661       11th       Never-married            Sales
# ...    ...        ...     ...        ...                 ...              ...
# 45170   90    Private   87285    HS-grad       Never-married    Other-service
# 45171   90    Private  313749    HS-grad             Widowed     Adm-clerical
# 45172   90    Private   46786  Bachelors  Married-civ-spouse            Sales
# 45173   90  Local-gov  188242    HS-grad       Never-married     Craft-repair
# 45174   90    Private   40388  Bachelors       Never-married  Exec-managerial
#
# ...

# %%
alldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45175 entries, 0 to 45174
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  category
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  income          45175 non-null  int64
#  12  encoded_salary  45175 non-null  int64
# dtypes: category(1), int64(5), object(7)
# memory usage: 4.2+ MB
